# %% [markdown]
# # python

# %%
print("Hello.........")
# Out:
# Hello.........

# %% [markdown]
# <h1>Hello</h1>

# %% [markdown]
# <h1 style="color:pink">Hello</h1>

# %% [markdown]
# <h3 style="color:red">Hello</h3>

# %% [markdown]
# <h4 style="color:blue">Hello</h4>

# %% [markdown]
# <h5 style="color:yellow">Hello python world</h5>

# %% [markdown]
# <h6 style="color:brown">Ruchi.....</h6>

# %% [markdown]
# # Python

# %% [markdown]
# # 1.Token

# %% [raw]
# I. Keyword(pre-define words)
# II. Punctuations(special symbols)/Delimiters
# III. Identifiers(Object name)
# IV. Literals(Constant value)
#                      1.Numberic------I.integers
#                                      II.float
#                                      III.complex
#
#                      2.String
#                      3.List
#                      4.Tuple
#                      5.Dictionary
#                      6.Boolean
#                      7.Set
#                      8.Frozenset
#
# V. Operators
# VI. Comments

# %% [raw]
# I. Keyword(pre-define words)
#       Predefined words that have special meaning in Python.
#
#       You cannot use them as variable names.

# %%
import keyword

all_keys = keyword.kwlist
print(all_keys)
print(len(all_keys))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
all_keys = keyword.softkwlist
print(all_keys)
print(len(all_keys))
# Out:
# ['_', 'case', 'match', 'type']
# 4

# %%
import string

lower_case = string.ascii_lowercase
print(lower_case)
print(len(lower_case))
print(string.ascii_lowercase)
# Out:
# abcdefghijklmnopqrstuvwxyz
# 26
# abcdefghijklmnopqrstuvwxyz

# %%
upper_case = string.ascii_uppercase
print(upper_case)3
print(len(upper_case))
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 26

# %%
import string
ascii_lowercase = "abcdefghijklmnopqrstuvwxyz"
ascii_uppercase = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
ascii_letters = ascii_lowercase + ascii_uppercase
print(ascii_letters)
print(len(ascii_letters))
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 52

# %%
import string
print(string.ascii_lowercase)

import keyword
print(keyword.kwlist)
# Out:
# abcdefghijklmnopqrstuvwxyz
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import keyword
all_key = keyword.kwlist
print(all_key)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
digits = string.digits
print(digits)
print(len(digits))
# Out:
# 0123456789
# 10

# %%
print(string.hexdigits)
# Out:
# 0123456789abcdefABCDEF

# %%
octdigits = string.octdigits
print(octdigits)
print(len(octdigits))
# Out:
# 01234567
# 8

# %%
II.Punctuators / Delimiters

Symbols used to structure the program.

Example:
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 32

# %%
punctuation = r"""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""
print(punctuation)
print(len(punctuation))

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
printable = string.printable
print(printable)
print(len(printable))
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#
#
# 100

# %% [raw]
# III. Identifiers
#
# Names given to variables, functions, classes, etc.
#
# Example:

# %%
name = "Ruchi"
age = 15
def greet(): pass

# %%
1x = 10
print(1)
# Out:
#   Cell In[2], line 1
#     1x = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 10
print(X)   # case sensetive language
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 x = 10
# ----> 2 print(X)
#
# NameError: name 'X' is not defined

# %%
_1 = 10
print(_1)
# Out:
# 10

# %%
Z = 171012025
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 Z = 171012025
# ----> 2 print(z)
#
# NameError: name 'z' is not defined

# %%
B = 34
print(B)
# Out:
# 34

# %%
# we didn't run this particular cell That why it's throwing error in below cell
J = 45

# %%
print(J)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(J)
#
# NameError: name 'J' is not defined

# %%
xyz = 17
print(xyz)
# Out:
# 17

# %%
print(Xyz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(Xyz)
#
# NameError: name 'Xyz' is not defined

# %% [raw]
# Note: we called constant value literals
# variables are also called identifiers
# (identifiers) x = 10 (literals)

# %% [raw]
# VI.Literals Types:-
#     Constant values (data) used in the code.
#
# 1.Numberic------I.integers → 10,-5
#                 II.float → 3.14
#                 III.complex
# 2.String → "Hello", 'Python'
# 3.List
# 4.Tuple
# 5.Dictionary
# 6.Boolean → True, False
# 7.Set
# 8.Frozenset

# %% [raw]
# V.Operators:--
#     Symbols that perform operations.
#     Example:
#     +  -  *  /  %  **  //   (Arithmetic)
#     == != > < >= <=         (Comparison)
#     and, or, not            (Logical)
#     = += -= *= /=           (Assignment)
#     in, not in              (Membership)
#     is, is not              (Identity)

# %% [raw]
# VI.Comments(some books don’t include, but practically treated as tokens)
# Non-executable notes for programmers.
# Example:
#     # This is a single-line comment
#     """ This is a multi-line comment "

# %% [raw]
# # Program to add two numbers
# a = 5       # Identifier + Literal
# b = 10      # Identifier + Literal
# sum = a+b   # Identifier + Operator
# print(sum)  # Keyword (built-in function)

# %% [raw]
# a, b, sum → Identifiers
#
# 5, 10 → Literals
#
# = , + → Operators
#
# print → Keyword (technically a built-in function but acts like keyword)
#
# # Program to add two numbers → Comment

# %% [markdown]
# # 1.Numberic --- I.Intergers

# %%
R = 567
print(type(R))
print(id(R))
# Out:
# <class 'int'>
# 2255096365776

# %% [markdown]
# ###  II.Float

# %%
# basic imp Question
N = 10.0
print(type(N))
print(id(N))
# Out:
# <class 'float'>
# 2255089258672

# %% [markdown]
# ### III Complex

# %%
# Complex = Real number + Imagainery number
H = 10 + 10j
print(type(H))
# Out:
# <class 'complex'>

# %%
Y = 0 + 0j
print(type(Y))
# Out:
# <class 'complex'>

# %%
I = j
print(type(I))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 I = j
#       2 print(type(I))
#
# NameError: name 'j' is not defined
